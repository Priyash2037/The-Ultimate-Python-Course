# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyash2037/The-Ultimate-Python-Course/blob/main/yes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip night.v1-night_clear.yolov8.zip -d /content/dataset
# Out:
# Archive:  night.v1-night_clear.yolov8.zip
#  extracting: /content/dataset/README.dataset.txt
#  extracting: /content/dataset/README.roboflow.txt
#  extracting: /content/dataset/data.yaml
#    creating: /content/dataset/train/
#    creating: /content/dataset/train/images/
#  extracting: /content/dataset/train/images/02730177-7989-4ed0-b05a-4ac361e84636_jpg.rf.d84f8ff42cacb069b5fce406d319c770.jpg
#  extracting: /content/dataset/train/images/0293332e-8614-4f7e-bbc7-fb34531212e1_jpg.rf.b01279d09ff88dc0d5d6b954b9cf093a.jpg
#  extracting: /content/dataset/train/images/02e35575-f76b-4395-a97a-27303bf41525_jpg.rf.3c4369b16aabfb1ed5cb072a86b8d6b8.jpg
#  extracting: /content/dataset/train/images/04160a63-6275-45d9-ad3c-f74d4ba9e819_jpg.rf.39785eeb09b1394e674e1d2508366ac7.jpg
#  extracting: /content/dataset/train/images/0419c9b8-a2f9-4871-8631-4312c1bd24c9_jpg.rf.a57953964855666c00135d41d7b5e7ba.jpg
# ...

# %%
# Install YOLOv8
# !pip install ultralytics

from ultralytics import YOLO

# Load a pre-trained YOLOv8 model (nano version for faster training)
model = YOLO('yolov8n.pt')

# Train the model
results = model.train(
    data='/content/dataset/data.yaml',  # <-- replace with actual path to data.yaml
    epochs=50,   # number of training epochs
    imgsz=320    # image size
)

print("✅ Training complete!")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.6 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
